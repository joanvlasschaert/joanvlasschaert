# %% [markdown]
# <a href="https://colab.research.google.com/github/joanvlasschaert/joanvlasschaert/blob/main/notebooks/image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Classification Using AutoML

# %% [markdown]
# In this notebook, we will see how we can simply create an image classification model with AutoML to pre-annotate our dataset on the [Kili Platform](https://cloud.kili-technology.com/label/).

# %% [markdown]
# ## Setup API key

# %% [markdown]
# We first setup the api key and automl path.

# %%
from getpass import getpass

# %%
KILI_URL="https://cloud.kili-technology.com/"  # If you are not using Kili SaaS, change the url to your configuration

api_endpoint = f"{KILI_URL}api/label/v2/graphql"

# %% [markdown]
# You can get your API key from the [Kili platform](https://cloud.kili-technology.com/label/my-account/api-key) and setup your environment variables. If you are working locally, please set your environment variables in a `.env` file. Also, if notebook is used on Colab, the Python path is redirected.

# %%
! pip install python-dotenv
# %reload_ext dotenv
# %dotenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-0.21.0
# cannot find .env file

# %%
from IPython import get_ipython
import os

if "google.colab" in str(get_ipython()):
    os.environ["PYTHONPATH"] += ":/content/automl/"
    api_key = getpass("Add your API Key here: ")
else:
    api_key = os.getenv("KILI_API_KEY")
# Out:
# Add your API Key here: ··········

# %% [markdown]
# ## Install

# %% [markdown]
# We will follow the install procedure explained in the [README.md](https://github.com/kili-technology/automl/blob/main/README.md).

# %%
# !git clone https://github.com/kili-technology/automl.git
# Out:
# Cloning into 'automl'...
# remote: Enumerating objects: 4643, done.
# remote: Counting objects: 100% (1539/1539), done.
# remote: Compressing objects: 100% (571/571), done.
# remote: Total 4643 (delta 1154), reused 1216 (delta 957), pack-reused 3104
# Receiving objects: 100% (4643/4643), 45.66 MiB | 28.13 MiB/s, done.
# Resolving deltas: 100% (2699/2699), done.

# %%
# %cd automl
# Out:
# /content/automl

# %% [markdown]
# Install the packages. This should take less than a minute.

# %%
# %%capture
# !git submodule update --init
# !pip install torch && pip install -e .

# %% [markdown]
# ## Imports

# %%
from tqdm.autonotebook import tqdm

from kili.client import Kili
# Out:
# <ipython-input-9-fdf65c4f08bf>:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# ## Setup a mock Kili project

# %% [markdown]
# Setup the kili connection.

# %%
kili = Kili(api_key=api_key, api_endpoint=api_endpoint)
# Out:
# /usr/local/lib/python3.8/dist-packages/kili/authentication.py:91: UserWarning: Kili Python SDK version should match with Kili API version.
# Please install version: "pip install kili==2.125.1"
#   warnings.warn(message, UserWarning)

# %% [markdown]
# ### Create the project

# %%
json_interface = {
    "jobRendererWidth": 0.2,
    "jobs": {
        "CLASSIFICATION_JOB": {
            "mlTask": "CLASSIFICATION",
            "content": {
                "categories": {
                    "VEHICLE": {
                        "name": "vehicle"
                    },
                    "NON_VEHICLE": {
                        "name": "non vehicle"
                    }
                },
                "input": "radio"
            },
            "required": 0,
            "isChild": False,
            "instruction": "Class of vehicle presence"
        }
    }
}

# %%
project = kili.create_project(
    title="AutoML demo - Image Classification (Vehicle Classification)",
    description="Classify vehicle presence",
    input_type="IMAGE",
    json_interface=json_interface
)

# %%
project_id = project["id"]

# %% [markdown]
# ### Add assets

# %%
vehicle_assets = [
    {
        "externalId": f"{i}",
        "content": f"https://storage.googleapis.com/kili-machine-learning-automl/notebooks/vehicle_classification/vehicles/image_{i}.png",
        "metadata": {}
    }
    for i in range(500)
]
non_vehicle_assets = [
    {
        "externalId": f"{len(vehicle_assets) + i}",
        "content": f"https://storage.googleapis.com/kili-machine-learning-automl/notebooks/vehicle_classification/non-vehicles/image_{i}.png",
        "metadata": {}
    }
    for i in range(500)
]
assets_to_import = vehicle_assets + non_vehicle_assets

# %% [markdown]
# Now we send the data to our Kili project.

# %%
external_id_array = [a.get("externalId") for a in assets_to_import]
content_array = [a.get("content") for a in assets_to_import]
json_metadata_array = [a.get("metadata") for a in assets_to_import]
kili.append_many_to_dataset(project_id=project_id, 
                            content_array=content_array,
                            external_id_array=external_id_array, 
                            json_metadata_array=json_metadata_array)
# Out:
# 100%|██████████| 1000/1000 [01:01<00:00, 16.23it/s]
# {'id': 'clba4yl4g008s0lwmhlu89h7e'}

# %% [markdown]
# ### Add labels to assets

# %% [markdown]
# We add labels to half of the data to simulate a project where we haven't labeled much data and we want to predict the labels of the unlabeled data.

# %%
assets = kili.assets(project_id=project_id, fields=["id", "externalId"], first=1000)

asset_ids = []
json_responses = []
for asset_id in tqdm(assets):
    external_id = int(asset_id["externalId"])

    if external_id < 300:
        asset_ids.append(asset_id["id"])
        json_responses.append({
                                  "CLASSIFICATION_JOB": {
                                      "categories": [{"name": "VEHICLE"}]
                                  }
                              })
    
    elif 499 < external_id < 800:
        asset_ids.append(asset_id["id"])
        json_responses.append({
                                  "CLASSIFICATION_JOB": {
                                      "categories": [{"name": "NON_VEHICLE"}]
                                  }
                              })
    else:
        pass

kili.append_labels(
    asset_ids,
    json_responses
)
# Out:
# 100%|██████████| 1000/1000 [00:02<00:00, 394.76it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [{'id': 'clba521rq00e30l03geoh8uhx'},
#  {'id': 'clba521rq00e40l039ksyfb7p'},
#  {'id': 'clba521rq00e50l03drm0htjy'},
#  {'id': 'clba521rq00e60l03h6vkfywp'},
#  {'id': 'clba521rq00e70l034gy10lro'},
#  {'id': 'clba521rr00e80l03218c6j3b'},
#  {'id': 'clba521rr00e90l0328y55fwy'},
#  {'id': 'clba521rr00ea0l031x0a0gay'},
#  {'id': 'clba521rr00eb0l0301sf61yx'},
#  {'id': 'clba521rr00ec0l038h1cem4j'},
#  {'id': 'clba521rr00ed0l03baki8z0u'},
#  {'id': 'clba521rr00ee0l031bzmdz3n'},
#  {'id': 'clba521rr00ef0l0313e8epy6'},
#  {'id': 'clba521rr00eg0l0360dlco1v'},
#  {'id': 'clba521rr00eh0l03gez73wu2'},
#  {'id': 'clba521rr00ei0l037uf3flpm'},
#  {'id': 'clba521rr00ej0l0357di4liu'},
#  {'id': 'clba521rr00ek0l033rmke80g'},
#  {'id': 'clba521rr00el0l03cnqwbkv9'},
#  {'id': 'clba521rs00em0l03cdmr3goa'},
#  {'id': 'clba521rs00en0l03edre0vf9'},
#  {'id': 'clba521rs00eo0l033diw4nr9'},
#  {'id': 'clba521rs00ep0l0336u7h17n'},
#  {'id': 'clba521rs00eq0l037yxsainc'},
#  {'id': 'clba528i200c40lvlgpqz8p7m'},
#  {'id': 'clba528i200c50lvlhfmygkr8'},
#  {'id': 'clba528i200c60lvl1u11byw0'},
#  {'id': 'clba528i200c70lvl0fjb3gb5'},
#  {'id': 'clba528i200c80lvlbhyaav6q'},
#  {'id': 'clba528i200c90lvl9ercbeii'},
#  {'id': 'clba528i200ca0lvl7yroe6pw'},
#  {'id': 'clba528i200cb0lvl21n73bnm'},
#  {'id': 'clba528i300cc0lvl0g4j3pza'},
#  {'id': 'clba528i300cd0lvl3xs0a4w0'},
#  {'id': 'clba528i300ce0lvlfsneejvc'},
#  {'id': 'clba528i300cf0lvl5rys4h0z'},
#  {'id': 'clba528i300cg0lvlezrh32l7'},
#  {'id': 'clba528i300ch0lvl51bo91k5'},
#  {'id': 'clba528i300ci0lvl3vh83s2g'},
#  {'id': 'clba528i300cj0lvlhwme26st'},
#  {'id': 'clba528i300ck0lvl3kng56w3'},
#  {'id': 'clba528i300cl0lvl5rjcawhd'},
#  {'id': 'clba528i400cm0lvl9rugak5v'},
#  {'id': 'clba528i400cn0lvl087lgheg'},
#  {'id': 'clba528i400co0lvlgcrfb8d3'},
#  {'id': 'clba528i400cp0lvlcdrbdvt3'},
#  {'id': 'clba528i400cq0lvl7sc69bex'},
#  {'id': 'clba528i400cr0lvlbza226fk'},
#  {'id': 'clba528i400cs0lvl08w25b8u'},
#  {'id': 'clba528i400ct0lvlhbz6gm3v'},
#  {'id': 'clba528i400cu0lvl66q23rpu'},
#  {'id': 'clba528i400cv0lvldwgj35ny'},
#  {'id': 'clba528i400cw0lvlafngalp8'},
#  {'id': 'clba528i500cx0lvl7d4gecxd'},
#  {'id': 'clba528i500cy0lvl4gzlfx6t'},
#  {'id': 'clba528i500cz0lvl346428zo'},
#  {'id': 'clba528i500d00lvl45xa2xk7'},
#  {'id': 'clba528i500d10lvl8o8z65sq'},
#  {'id': 'clba528i500d20lvlel9fczur'},
#  {'id': 'clba528i500d30lvl6hor62rl'},
#  {'id': 'clba528i500d40lvlf6aq6nrb'},
#  {'id': 'clba528i500d50lvl2yt3chcv'},
#  {'id': 'clba528i500d60lvl0bgl78xw'},
#  {'id': 'clba528i500d70lvlhy5yb42a'},
#  {'id': 'clba528i600d80lvlhu4v1sig'},
#  {'id': 'clba528i600d90lvl1o8eblaq'},
#  {'id': 'clba528i600da0lvlb73j12s2'},
#  {'id': 'clba528i600db0lvldjr5a0nf'},
#  {'id': 'clba528i600dc0lvl218bc7m0'},
#  {'id': 'clba528i600dd0lvl1m0d3qge'},
#  {'id': 'clba528i600de0lvlh7k60h6n'},
#  {'id': 'clba528i600df0lvlbi8m4j6h'},
#  {'id': 'clba528i600dg0lvldk3tas40'},
#  {'id': 'clba528i600dh0lvldpmz3ub7'},
#  {'id': 'clba528i600di0lvl83jwa5my'},
#  {'id': 'clba528i600dj0lvla5qc9waz'},
#  {'id': 'clba528i700dk0lvl7gjcf4li'},
#  {'id': 'clba528i700dl0lvlfedcfg4e'},
#  {'id': 'clba52kc900g50lwm0tst9kcu'},
#  {'id': 'clba52kca00g60lwm0jgb7nbz'},
#  {'id': 'clba52kca00g70lwma1w92a2k'},
#  {'id': 'clba52kca00g80lwm8zo2d0mu'},
#  {'id': 'clba52kca00g90lwm5t49h951'},
#  {'id': 'clba52kca00ga0lwm1mza5gxy'},
#  {'id': 'clba52kca00gb0lwm3ms7f9yn'},
#  {'id': 'clba52kca00gc0lwmdyxk1olr'},
#  {'id': 'clba52kca00gd0lwm08dug9uv'},
#  {'id': 'clba52kca00ge0lwmajwg3e9z'},
#  {'id': 'clba52kca00gf0lwm5oik3x5j'},
#  {'id': 'clba52kca00gg0lwmhr613de8'},
#  {'id': 'clba52kca00gh0lwmdr8w14hd'},
#  {'id': 'clba52kca00gi0lwm73rea5rq'},
#  {'id': 'clba52kca00gj0lwmhlnu9684'},
#  {'id': 'clba52kca00gk0lwm2kn366gz'},
#  {'id': 'clba52kca00gl0lwm9ehz7iec'},
#  {'id': 'clba52kca00gm0lwm339x03rj'},
#  {'id': 'clba52kca00gn0lwmbiou5nus'},
#  {'id': 'clba52kca00go0lwm6aje9thg'},
#  {'id': 'clba52kca00gp0lwm3iiy1kea'},
#  {'id': 'clba52kca00gq0lwm7xzuegyt'},
#  {'id': 'clba52kca00gr0lwmdihp36hr'},
#  {'id': 'clba52kca00gs0lwm0wmj5drq'},
#  {'id': 'clba52kca00gt0lwmgtv75pje'},
#  {'id': 'clba52kca00gu0lwmcb30b0w5'},
#  {'id': 'clba52kcb00gv0lwm5gfh0qmd'},
#  {'id': 'clba52kcb00gw0lwmg8by47zo'},
#  {'id': 'clba52kcb00gx0lwmgguv073d'},
#  {'id': 'clba52kcb00gy0lwm7oeje8sr'},
#  {'id': 'clba52kcb00gz0lwmggd5468z'},
#  {'id': 'clba52kcb00h00lwm2mjp9toe'},
#  {'id': 'clba52kcb00h10lwmf5q6ggad'},
#  {'id': 'clba52kcb00h20lwme49u72kc'},
#  {'id': 'clba52kcb00h30lwm0c2q4t2j'},
#  {'id': 'clba52kcb00h40lwm3gcmhau4'},
#  {'id': 'clba52kcb00h50lwma8f91a4j'},
#  {'id': 'clba52kcb00h60lwmhq1c4xls'},
#  {'id': 'clba52kcb00h70lwmcgkr7kw4'},
#  {'id': 'clba52kcb00h80lwmadltbmhd'},
#  {'id': 'clba52kcb00h90lwm6dc323d0'},
#  {'id': 'clba52kcb00ha0lwmb4ki2wnn'}]

# %% [markdown]
# You can now click on the following link to see the assets in your project:

# %%
print(f"{KILI_URL}label/projects/{project_id}/menu/queue?currentPage=1&pageSize=20")
# Out:
# https://cloud.kili-technology.com/label/projects/clba4yl4g008s0lwmhlu89h7e/menu/queue?currentPage=1&pageSize=20

# %% [markdown]
# ## Training a image classifier with Kiliautoml

# %% [markdown]
# The following command will automatically download the labeled data in your Kili project. Then, it will choose the right model for your task, train it with this data and save it locally.

# %%
# !kiliautoml train \
    --api-key $api_key \
    --project-id $project_id \
    --epochs 30
# Out:
# Loading KiliAutoML...
# /usr/local/lib/python3.8/dist-packages/kili/authentication.py:91: UserWarning: Kili Python SDK version should match with Kili API version.
# Please install version: "pip install kili==2.125.1"
#   warnings.warn(message, UserWarning)
# 100% 1/1 [00:00<00:00,  2.08it/s]
# KiliAutoML INFO Training on job: CLASSIFICATION_JOB
# KiliAutoML INFO Downloading assets with status in ['LABELED', 'TO_REVIEW', 'REVIEWED'] from Kili project
# cache_path /root/.cache/kili/automl/clba4yl4g008s0lwmhlu89h7e/get_asset_memoized
# ________________________________________________________________________________
# [Memory] Calling kiliautoml.utils.helpers.get_asset_memoized...
# get_asset_memoized(kili=Kili(), project_id='clba4yl4g008s0lwmhlu89h7e', total=None, skip=0, status_in=['LABELED', 'TO_REVIEW', 'REVIEWED'], asset_filter=None)
# 100% 600/600 [00:08<00:00, 66.80it/s]
# _______________________________________________get_asset_memoized - 9.4s, 0.2min
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 1
# wandb: You chose 'Create a W&B account'
# wandb: Create an account here: https://wandb.ai/authorize?signup=true
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /root/.cache/kili/automl/clba4yl4g008s0lwmhlu89h7e/CLASSIFICATION_JOB/wandb/run-20221205_015911-2pcev5j6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run amber-capybara-1
# wandb: ⭐️ View project at https://wandb.ai/joanoceancleanup/AutoML%20demo%20-%20Image%20Classification%20%28Vehicle%20Classification%29_CLASSIFICATION_JOB
# wandb: 🚀 View run at https://wandb.ai/joanoceancleanup/AutoML%20demo%20-%20Image%20Classification%20%28Vehicle%20Classification%29_CLASSIFICATION_JOB/runs/2pcev5j6
# KiliAutoML INFO defaulting to model_name=efficientnet_b0
# KiliAutoML INFO Downloading images to folder /root/.cache/kili/automl/clba4yl4g008s0lwmhlu89h7e/CLASSIFICATION_JOB/torchvision/data
# Downloading images:   0% 0/600 [00:00<?, ?it/s]KiliAutoML INFO Downloading public asset
# response.status_code: 401 <Response [401]> 401 https://storage.googleapis.com/kili-machine-learning-automl/notebooks/vehicle_classification/non-vehicles/image_236.png
# Downloading images: 100% 600/600 [03:22<00:00,  2.97it/s]
# KiliAutoML INFO Initialization of the model with N=2 classes
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-3dd342df.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-3dd342df.pth
# 100% 20.5M/20.5M [00:00<00:00, 75.7MB/s]
# KiliAutoML INFO Start model training on device: cuda:0
# Training - Epoch:   0% 0/30 [00:00<?, ?it/s]KiliAutoML INFO ----------
# Training - Epoch:   3% 1/30 [00:11<05:41, 11.78s/it]KiliAutoML INFO ----------
# Training - Epoch:   7% 2/30 [00:15<03:21,  7.18s/it]KiliAutoML INFO ----------
# Training - Epoch:  10% 3/30 [00:19<02:34,  5.71s/it]KiliAutoML INFO ----------
# Training - Epoch:  13% 4/30 [00:23<02:10,  5.02s/it]KiliAutoML INFO ----------
# Training - Epoch:  17% 5/30 [00:27<01:56,  4.65s/it]KiliAutoML INFO ----------
# Training - Epoch:  20% 6/30 [00:31<01:46,  4.42s/it]KiliAutoML INFO ----------
# Training - Epoch:  23% 7/30 [00:35<01:38,  4.26s/it]KiliAutoML INFO ----------
# Training - Epoch:  27% 8/30 [00:39<01:32,  4.19s/it]KiliAutoML INFO ----------
# Training - Epoch:  30% 9/30 [00:43<01:26,  4.12s/it]KiliAutoML INFO ----------
# Training - Epoch:  33% 10/30 [00:47<01:21,  4.06s/it]KiliAutoML INFO ----------
media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /root/.cache/kili/automl/clba4yl4g008s0lwmhlu89h7e/CLASSIFICATION_JOB/wandb/run-20221205_015911-2pcev5j6/logs
# KiliAutoML INFO Summary of training:
# CLASSIFICATION_JOB      accuracy      f1      loss    precision    recall
# --------------------  ----------  ------  --------  -----------  --------
# train_NON_VEHICLE         nan     0.9504  nan            0.9481    0.9526
# train_VEHICLE             nan     0.9496  nan            0.9519    0.9474
# train__overall              0.95  0.95      0.1428       0.95      0.95
# val_NON_VEHICLE           nan     1       nan            1         1
# val_VEHICLE               nan     1       nan            1         1
# val__overall                1     1         0.0325       1         1
# KiliAutoML SUCCESS train command finished successfully!

# %% [markdown]
# ### Send predictions

# %% [markdown]
# Now we can use our local trained model to predict the classes of our image assets and send the prediction scores to the project on Kili. These preannotations can then be validated or corrected by annotators.

# %%
# !kiliautoml predict \
    --api-key $api_key \
    --project-id $project_id
# Out:
# Loading KiliAutoML...
# KiliAutoML INFO Are you sure You want to send the predictions to Kili? Y/N
# y
# KiliAutoML INFO OK, We will send the predictions to Kili!
# /usr/local/lib/python3.8/dist-packages/kili/authentication.py:91: UserWarning: Kili Python SDK version should match with Kili API version.
# Please install version: "pip install kili==2.125.1"
#   warnings.warn(message, UserWarning)
# 100% 1/1 [00:00<00:00,  2.01it/s]
# KiliAutoML INFO Downloading assets with status in ['TODO', 'ONGOING'] from Kili project
# cache_path /root/.cache/kili/automl/clba4yl4g008s0lwmhlu89h7e/get_asset_memoized
# ________________________________________________________________________________
# [Memory] Calling kiliautoml.utils.helpers.get_asset_memoized...
# get_asset_memoized(kili=Kili(), project_id='clba4yl4g008s0lwmhlu89h7e', total=None, skip=0, status_in=['TODO', 'ONGOING'], asset_filter=None)
# 100% 400/400 [00:01<00:00, 205.03it/s]
# _______________________________________________get_asset_memoized - 2.1s, 0.0min
# KiliAutoML INFO Predicting annotations for job: CLASSIFICATION_JOB
# KiliAutoML INFO defaulting to model_name=efficientnet_b0
# KiliAutoML INFO Downloading images to folder /root/.cache/kili/automl/clba4yl4g008s0lwmhlu89h7e/CLASSIFICATION_JOB/torchvision/data
# Downloading images:   0% 0/400 [00:00<?, ?it/s]KiliAutoML INFO Downloading public asset
# response.status_code: 401 <Response [401]> 401 https://storage.googleapis.com/kili-machine-learning-automl/notebooks/vehicle_classification/non-vehicles/image_349.png
# Downloading images: 100% 400/400 [01:41<00:00,  3.92it/s]
# KiliAutoML INFO Initialization of the model with N=2 classes
# Complete: 98.0%
# TypeErrorTraceback (most recent call last)
# /usr/bin/kiliautoml in <module>
#      31 if __name__ == '__main__':
#      32     sys.argv[0] = re.sub(r'(-script\.pyw?|\.exe)?$', '', sys.argv[0])
# ---> 33     sys.exit(load_entry_point('kiliautoml', 'console_scripts', 'kiliautoml')())
#         global sys.exit = <built-in function exit>
#         global load_entry_point = <function importlib_load_entry_point at 0x7fcb0266b1f0>
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in __call__(self=<Group kiliautoml>, *args=(), **kwargs={})
#    1128     def __call__(self, *args: t.Any, **kwargs: t.Any) -> t.Any:
#    1129         """Alias for :meth:`main`."""
# -> 1130         return self.main(*args, **kwargs)
#         self.main = <bound method BaseCommand.main of <Group kiliautoml>>
#         args = ()
#         kwargs = {}
#    1131
#    1132
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in main(self=<Group kiliautoml>, args=['predict', '--api-key', '41d1dd6f-fb37-4d17-9efa-b0e1dd074194', '--project-id', 'clba4yl4g008s0lwmhlu89h7e'], prog_name='kiliautoml', complete_var=None, standalone_mode=True, windows_expand_args=True, **extra={})
#    1053             try:
#    1054                 with self.make_context(prog_name, args, **extra) as ctx:
# -> 1055                     rv = self.invoke(ctx)
#         rv = undefined
#         self.invoke = <bound method MultiCommand.invoke of <Group kiliautoml>>
#         ctx = <click.core.Context object at 0x7fcb023cd9a0>
#    1056                     if not standalone_mode:
#    1057                         return rv
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in invoke(self=<Group kiliautoml>, ctx=<click.core.Context object>)
#    1655                 sub_ctx = cmd.make_context(cmd_name, args, parent=ctx)
#    1656                 with sub_ctx:
# -> 1657                     return _process_result(sub_ctx.command.invoke(sub_ctx))
#         _process_result = <function MultiCommand.invoke.<locals>._process_result at 0x7fcb023f7f70>
#         sub_ctx.command.invoke = <bound method Command.invoke of <Command main>>
#         sub_ctx = <click.core.Context object at 0x7fcafec39220>
#    1658
#    1659         # In chain mode we create the contexts step by step, but after the
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in invoke(self=<Command main>, ctx=<click.core.Context object>)
#    1402
#    1403         if self.callback is not None:
# -> 1404             return ctx.invoke(self.callback, **ctx.params)
#         ctx.invoke = <bound method Context.invoke of <click.core.Context object at 0x7fcafec39220>>
#         self.callback = <function main at 0x7fca08e0f0d0>
#         ctx.params = {'api_key': '41d1dd6f-fb37-4d17-9efa-b0e1dd074194', 'project_id': 'clba4yl4g008s0lwmhlu89h7e', 'api_endpoint': 'https://cloud.kili-technology.com/api/label/v2/graphql', 'ml_backend': 'pytorch', 'model_name': None, 'model_repository': None, 'target_job': (), 'ignore_job': (), 'randomize_assets': True, 'max_assets': None, 'clear_dataset_cache': False, 'batch_size': 8, 'parity_filter': 'none', 'verbose': 'INFO', 'asset_status_in': ['TODO', 'ONGOING'], 'model_path': None, 'from_project': None, 'dry_run': False}
#    1405
#    1406     def shell_complete(self, ctx: Context, incomplete: str) -> t.List["CompletionItem"]:
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in invoke(_Context__self=<click.core.Context object>, _Context__callback=<function main>, *args=(), **kwargs={'api_endpoint': 'https://cloud.kili-technology.com/api/label/v2/graphql', 'api_key': '41d1dd6f-fb37-4d17-9efa-b0e1dd074194', 'asset_status_in': ['TODO', 'ONGOING'], 'batch_size': 8, 'clear_dataset_cache': False, 'dry_run': False, 'from_project': None, 'ignore_job': (), 'max_assets': None, 'ml_backend': 'pytorch', ...})
#     758         with augment_usage_errors(__self):
#     759             with ctx:
# --> 760                 return __callback(*args, **kwargs)
#         global __callback = undefined
#         args = ()
#         kwargs = {'api_key': '41d1dd6f-fb37-4d17-9efa-b0e1dd074194', 'project_id': 'clba4yl4g008s0lwmhlu89h7e', 'api_endpoint': 'https://cloud.kili-technology.com/api/label/v2/graphql', 'ml_backend': 'pytorch', 'model_name': None, 'model_repository': None, 'target_job': (), 'ignore_job': (), 'randomize_assets': True, 'max_assets': None, 'clear_dataset_cache': False, 'batch_size': 8, 'parity_filter': 'none', 'verbose': 'INFO', 'asset_status_in': ['TODO', 'ONGOING'], 'model_path': None, 'from_project': None, 'dry_run': False}
#     761
#     762     def forward(
#
# /content/automl/commands/predict.py in main(project_id='clba4yl4g008s0lwmhlu89h7e', api_endpoint='https://cloud.kili-technology.com/api/label/v2/graphql', api_key='41d1dd6f-fb37-4d17-9efa-b0e1dd074194', asset_status_in=['TODO', 'ONGOING'], target_job=(), ignore_job=(), dry_run=False, model_path=None, verbose='INFO', max_assets=None, randomize_assets=True, from_project=None, parity_filter='none', model_name=None, model_repository=None, ml_backend='pytorch', batch_size=8, clear_dataset_cache=False)
#     131
#     132         if not dry_run and job_predictions and job_predictions.external_id_array:
# --> 133             kili.create_predictions(
#         kili.create_predictions = <bound method MutationsLabel.create_predictions of Kili()>
#         project_id = 'clba4yl4g008s0lwmhlu89h7e'
#         global external_id_array = undefined
#         job_predictions.external_id_array = ['849', '394', '458', '464', '846', '828', '490', '422', '857', '892', '492', '905', '338', '938', '947', '964', '343', '817', '399', '353
['efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'eff ...
#         generate_variables = <function MutationsLabel.create_predictions.<locals>.generate_variables at 0x7fca0845fca0>
#         global GQL_CREATE_PREDICTIONS = '\nmutation(\n    $data: CreatePredictionsData!\n    $where: AssetWhere!\n) {\n  data: createPredictions(\n    data: $data\n    where: $where\n  ) {\n      \nid\n\n  }\n}\n'
#      90             self,
#      91             properties_to_batch,
#
# /usr/local/lib/python3.8/dist-packages/kili/utils/pagination.py in _mutate_from_paginated_call(self=Kili(), properties_to_batch={'external_id_array': ['849', '394', '458', '464', '846', '828', '490', '422', '857', '892', '492', '905', '338', '938', '947', '964', '343', '817', '399', '353', ...], 'json_response_array': [{'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9909877, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.63841885, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.65294963, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9321158, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.98080504, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.98486495, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99345934, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99872595, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.82110584, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9607533, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99976414, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.98741454, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99542964, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.90513426, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99265665, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.98345554, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9533172, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.974697, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9392519, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9514286, 'name': 'VEHICLE'}]}}, ...], 'model_name_array': ['efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', ...]}, generate_variables=<function MutationsLabel.create_predictions.<locals>.generate_variables>, request='\nmutation(\n    $data: CreatePredictionsData!\n   ...: $data\n    where: $where\n  ) {\n      \nid\n\n  }\n}\n', batch_size=100)
#     166     results = []
#     167     for batch_number, batch in enumerate(batch_object_builder(properties_to_batch, batch_size)):
# --> 168         payload = generate_variables(batch)
#         payload = undefined
#         generate_variables = <function MutationsLabel.create_predictions.<locals>.generate_variables at 0x7fca0845fca0>
#         batch = {'external_id_array': ['849', '394', '458', '464', '846', '828', '490', '422', '857', '892', '492', '905', '338', '938', '947', '964', '343', '817', '399', '353', '871', '469', '851', '377', '309', '368', '498', '302', '967', '972', '859', '853', '844', '809', '355', '334', '954', '880', '359', '843', '986', '889', '830', '980', '329', '931', '840', '397', '922', '443', '475', '366', '951', '345', '827', '444', '813', '375', '974', '935', '388', '985', '326', '372', '480', '331', '926', '430', '427', '423', '848', '933', '310', '365', '945', '949', '884', '364', '462', '385', '454', '420', '930', '825', '820', '374', '406', '803', '337', '811', '868', '831', '936', '467', '465', '393', '389', '956', '918', '470'], 'model_name_array': ['efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0'], 'json_response_array': [{'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.9909877}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.63841885}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.65294963}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.9321158}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.98080504}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.98486495}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.99345934}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.99872595}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.82110584}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.9607533}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.99976414}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.98741454}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.99542964}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.90513426}]}}, {'CLASSIFICATION_JOB': {'categories ...
#     169         result = api_throttle(self.auth.client.execute)(request, payload)
#     170         results.append(result)
#
# /usr/local/lib/python3.8/dist-packages/kili/mutations/label/__init__.py in generate_variables(batch={'external_id_array': ['849', '394', '458', '464', '846', '828', '490', '422', '857', '892', '492', '905', '338', '938', '947', '964', '343', '817', '399', '353', ...], 'json_response_array': [{'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9909877, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.63841885, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.65294963, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9321158, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.98080504, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.98486495, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99345934, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99872595, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.82110584, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9607533, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99976414, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.98741454, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99542964, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.90513426, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.99265665, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.98345554, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9533172, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.974697, 'name': 'NON_VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9392519, 'name': 'VEHICLE'}]}}, {'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9514286, 'name': 'VEHICLE'}]}}, ...], 'model_name_array': ['efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', ...]})
#      79                 "data": {
#      80                     "modelNameArray": batch["model_name_array"],
# ---> 81                     "jsonResponseArray": [dumps(elem) for elem in batch["json_response_array"]],
#         global dumps = <function dumps at 0x7fcb01949160>
#         global elem = undefined
#         batch = {'external_id_array': ['849', '394', '458', '464', '846', '828', '490', '422', '857', '892', '492', '905', '338', '938', '947', '964', '343', '817', '399', '353', '871', '469', '851', '377', '309', '368', '498', '302', '967', '972', '859', '853', '844', '809', '355', '334', '954', '880', '359', '843', '986', '889', '830', '980', '329', '931', '840', '397', '922', '443', '475', '366', '951', '345', '827', '444', '813', '375', '974', '935', '388', '985', '326', '372', '480', '331', '926', '430', '427', '423', '848', '933', '310', '365', '945', '949', '884', '364', '462', '385', '454', '420', '930', '825', '820', '374', '406', '803', '337', '811', '868', '831', '936', '467', '465', '393', '389', '956', '918', '470'], 'model_name_array': ['efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0', 'efficientnet_b0'], 'json_response_array': [{'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.9909877}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.63841885}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.65294963}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.9321158}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.98080504}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.98486495}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.99345934}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.99872595}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.82110584}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.9607533}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.99976414}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.98741454}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'VEHICLE', 'confidence': 0.99542964}]}}, {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.90513426}]}}, {'CLASSIFICATION_JOB': {'categories ...
#      82                 },
#      83                 "where": {
#
# /usr/local/lib/python3.8/dist-packages/kili/mutations/label/__init__.py in <listcomp>(.0=<list_iterator object>)
#      79                 "data": {
#      80                     "modelNameArray": batch["model_name_array"],
# ---> 81                     "jsonResponseArray": [dumps(elem) for elem in batch["json_response_array"]],
#         global dumps = <function dumps at 0x7fcb01949160>
#         elem = {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.9909877}]}}
#         global batch = undefined
#      82                 },
#      83                 "where": {
#
# /usr/lib/python3.8/json/__init__.py in dumps(obj={'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9909877, 'name': 'NON_VEHICLE'}]}}, skipkeys=False, ensure_ascii=True, check_circular=True, allow_nan=True, cls=None, indent=None, separators=None, default=None, sort_keys=False, **kw={})
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#         global _default_encoder.encode = <bound method JSONEncoder.encode of <json.encoder.JSONEncoder object at 0x7fcb0192b5e0>>
#         obj = {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.9909877}]}}
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# /usr/lib/python3.8/json/encoder.py in encode(self=<json.encoder.JSONEncoder object>, o={'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9909877, 'name': 'NON_VEHICLE'}]}})
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#         chunks = undefined
#         self.iterencode = <bound method JSONEncoder.iterencode of <json.encoder.JSONEncoder object at 0x7fcb0192b5e0>>
#         o = {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.9909877}]}}
#         global _one_shot = undefined
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.8/json/encoder.py in iterencode(self=<json.encoder.JSONEncoder object>, o={'CLASSIFICATION_JOB': {'categories': [{'confidence': 0.9909877, 'name': 'NON_VEHICLE'}]}}, _one_shot=True)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#         _iterencode = <_json.Encoder object at 0x7fca07b85b20>
#         o = {'CLASSIFICATION_JOB': {'categories': [{'name': 'NON_VEHICLE', 'confidence': 0.9909877}]}}
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/lib/python3.8/json/encoder.py in default(self=<json.encoder.JSONEncoder object>, o=0.9909877)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#         global TypeError = undefined
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type float32 is not JSON serializable

# %% [markdown]
# Now you can ckeck that your assets have predictions on [Kili](https://cloud.kili-technology.com/)!

# %%
print(f"{KILI_URL}label/projects/{project_id}/menu/queue?currentPage=1&pageSize=20")

# %% [markdown]
# ### Label Errors

# %% [markdown]
# You can add wrong labels to a small portion of the data to simulate a project where some data is incorrectly labeled.

# %%
assets = kili.assets(project_id=project_id, fields=["id", "externalId"])

asset_ids = []
json_responses = []
for asset in tqdm(assets):

    external_id = int(asset["externalId"])
    if 299 < external_id < 310:
        asset_ids.append(asset_id["id"])
        json_responses.append({
                                  "CLASSIFICATION_JOB": {
                                      "categories": [{"name": "NON_VEHICLE"}]
                                  }
                              })

    elif 799 < external_id < 810:
        asset_ids.append(asset_id["id"])
        external_id = int(asset["externalId"])
        json_responses.append({
                                  "CLASSIFICATION_JOB": {
                                      "categories": [{"name": "VEHICLE"}]
                                  }
                              })

kili.append_labels(
    asset_ids,
    json_responses
)
# Out:
# 100%|██████████| 1000/1000 [00:02<00:00, 376.75it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [{'id': 'clba5o6ws00tv0lxs2t0labb6'},
#  {'id': 'clba5o6ws00tw0lxs19a5f0t5'},
#  {'id': 'clba5o6ws00tx0lxsek5a0fz0'},
#  {'id': 'clba5o6ws00ty0lxs79wxa72l'},
#  {'id': 'clba5o6ws00tz0lxscj4m1vi2'},
#  {'id': 'clba5o6ws00u00lxs704yd9hk'},
#  {'id': 'clba5o6ws00u10lxshgnl7k8c'},
#  {'id': 'clba5o6ws00u20lxs6kve3maa'},
#  {'id': 'clba5o6ws00u30lxsba0447nn'},
#  {'id': 'clba5o6wt00u40lxs6v1g8lis'},
#  {'id': 'clba5o6wt00u50lxs1xp329tn'},
#  {'id': 'clba5o6wt00u60lxsa7ve1nxv'},
#  {'id': 'clba5o6wt00u70lxscwkbc74y'},
#  {'id': 'clba5o6wt00u80lxsbzw276eu'},
#  {'id': 'clba5o6wt00u90lxs4c2hf82u'},
#  {'id': 'clba5o6wt00ua0lxsglvifbv6'},
#  {'id': 'clba5o6wt00ub0lxs4t47f33w'},
#  {'id': 'clba5o6wt00uc0lxscfk90owp'},
#  {'id': 'clba5o6wt00ud0lxs2a0m1e25'},
#  {'id': 'clba5o6wt00ue0lxsb00009m5'}]

# %% [markdown]
# This command analyses the labeled data to detect potential labeling errors and sends warnings to the concerned assets. The user can then use the `potential_label_error` filter on the project's asset exploration to find the potentially problematic assets.

# %%
# !kiliautoml label_errors \
    --api-key $api_key \
    --project-id $project_id
# Out:
# Loading KiliAutoML...
# KiliAutoML INFO Are you sure You want to send the label errors to Kili? Y/N
# y
# KiliAutoML INFO OK, We will send the label errors to Kili!
# /usr/local/lib/python3.8/dist-packages/kili/authentication.py:91: UserWarning: Kili Python SDK version should match with Kili API version.
# Please install version: "pip install kili==2.125.1"
#   warnings.warn(message, UserWarning)
# 100% 1/1 [00:00<00:00,  2.08it/s]
# KiliAutoML INFO Detecting errors for job: CLASSIFICATION_JOB
# KiliAutoML INFO Downloading assets with status in ['LABELED', 'TO_REVIEW', 'REVIEWED'] from Kili project
# cache_path /root/.cache/kili/automl/clba4yl4g008s0lwmhlu89h7e/get_asset_memoized
# KiliAutoML INFO defaulting to model_name=efficientnet_b0
# KiliAutoML INFO Downloading images to folder /root/.cache/kili/automl/clba4yl4g008s0lwmhlu89h7e/CLASSIFICATION_JOB/torchvision/data
# Downloading images: 100% 600/600 [00:07<00:00, 78.60it/s]
# Training and predicting on several folds:   0% 0/4 [00:00<?, ?it/s]KiliAutoML INFO Initialization of the model with N=2 classes
# KiliAutoML INFO Start model training on device: cuda:0
#
# Training - Epoch:   0% 0/50 [00:00<?, ?it/s]KiliAutoML INFO ----------
#
# Training - Epoch:   2% 1/50 [00:05<04:29,  5.51s/it]KiliAutoML INFO ----------
#
# Training - Epoch:
  3.25s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  86% 43/50 [02:20<00:22,  3.25s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  88% 44/50 [02:23<00:19,  3.25s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  90% 45/50 [02:26<00:16,  3.24s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  92% 46/50 [02:30<00:13,  3.35s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  94% 47/50 [02:34<00:10,  3.65s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  96% 48/50 [02:37<00:07,  3.54s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  98% 49/50 [02:41<00:03,  3.45s/it]KiliAutoML INFO ----------
#
# Training - Epoch: 100% 50/50 [02:44<00:00,  3.29s/it]
# KiliAutoML SUCCESS Training complete in 2m 44s
# Training and predicting on several folds:  75% 3/4 [08:21<02:46, 166.42s/it]KiliAutoML INFO Initialization of the model with N=2 classes
# KiliAutoML INFO Start model training on device: cuda:0
#
# Training - Epoch:   0% 0/50 [00:00<?, ?it/s]KiliAutoML INFO ----------
#
# Training - Epoch:   2% 1/50 [00:03<02:41,  3.31s/it]KiliAutoML INFO ----------
#
# Training - Epoch:   4% 2/50 [00:06<02:38,  3.30s/it]KiliAutoML INFO ----------
#
# Training - Epoch:   6% 3/50 [00:09<02:34,  3.29s/it]KiliAutoML INFO ----------
#
# Training - Epoch:   8% 4/50 [00:13<02:31,  3.30s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  10% 5/50 [00:16<02:28,  3.30s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  12% 6/50 [00:19<02:25,  3.30s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  14% 7/50 [00:23<02:21,  3.29s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  16% 8/50 [00:26<02:18,  3.29s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  18% 9/50 [00:29<02:15,  3.30s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  20% 10/50 [00:32<02:11,  3.29s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  22% 11/50 [00:36<02:08,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  24% 12/50 [00:39<02:04,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  26% 13/50 [00:42<02:01,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  28% 14/50 [00:46<01:58,  3.29s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  30% 15/50 [00:49<01:54,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  32% 16/50 [00:52<01:51,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  34% 17/50 [00:55<01:48,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  36% 18/50 [00:59<01:44,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  38% 19/50 [01:02<01:41,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  40% 20/50 [01:05<01:37,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  42% 21/50 [01:08<01:34,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  44% 22/50 [01:12<01:31,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  46% 23/50 [01:15<01:28,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  48% 24/50 [01:18<01:24,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  50% 25/50 [01:21<01:21,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  52% 26/50 [01:25<01:18,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  54% 27/50 [01:28<01:15,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  56% 28/50 [01:31<01:12,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  58% 29/50 [01:35<01:09,  3.29s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  60% 30/50 [01:38<01:05,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  62% 31/50 [01:41<01:02,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  64% 32/50 [01:44<00:58,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  66% 33/50 [01:48<00:55,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  68% 34/50 [01:51<00:52,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  70% 35/50 [01:54<00:49,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  72% 36/50 [01:58<00:45,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  74% 37/50 [02:01<00:42,  3.28s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  76% 38/50 [02:04<00:39,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  78% 39/50 [02:07<00:35,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  80% 40/50 [02:11<00:32,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  82% 41/50 [02:14<00:29,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  84% 42/50 [02:17<00:26,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  86% 43/50 [02:20<00:22,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  88% 44/50 [02:24<00:19,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  90% 45/50 [02:27<00:16,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  92% 46/50 [02:30<00:13,  3.27s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  94% 47/50 [02:33<00:09,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  96% 48/50 [02:37<00:06,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch:  98% 49/50 [02:40<00:03,  3.26s/it]KiliAutoML INFO ----------
#
# Training - Epoch: 100% 50/50 [02:43<00:00,  3.27s/it]
# KiliAutoML SUCCESS Training complete in 2m 44s
# Training and predicting on several folds: 100% 4/4 [11:05<00:00, 166.45s/it]
# KiliAutoML INFO
# Updating metadata for the concerned assets
# KiliAutoML INFO Number of wrong labels found:
#
# ValueErrorTraceback (most recent call last)
# /usr/bin/kiliautoml in <module>
#      31 if __name__ == '__main__':
#      32     sys.argv[0] = re.sub(r'(-script\.pyw?|\.exe)?$', '', sys.argv[0])
# ---> 33     sys.exit(load_entry_point('kiliautoml', 'console_scripts', 'kiliautoml')())
#         global sys.exit = <built-in function exit>
#         global load_entry_point = <function importlib_load_entry_point at 0x7f782ad151f0>
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in __call__(self=<Group kiliautoml>, *args=(), **kwargs={})
#    1128     def __call__(self, *args: t.Any, **kwargs: t.Any) -> t.Any:
#    1129         """Alias for :meth:`main`."""
# -> 1130         return self.main(*args, **kwargs)
#         self.main = <bound method BaseCommand.main of <Group kiliautoml>>
#         args = ()
#         kwargs = {}
#    1131
#    1132
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in main(self=<Group kiliautoml>, args=['label_errors', '--api-key', '41d1dd6f-fb37-4d17-9efa-b0e1dd074194', '--project-id', 'clba4yl4g008s0lwmhlu89h7e'], prog_name='kiliautoml', complete_var=None, standalone_mode=True, windows_expand_args=True, **extra={})
#    1053             try:
#    1054                 with self.make_context(prog_name, args, **extra) as ctx:
# -> 1055                     rv = self.invoke(ctx)
#         rv = undefined
#         self.invoke = <bound method MultiCommand.invoke of <Group kiliautoml>>
#         ctx = <click.core.Context object at 0x7f782aa779a0>
#    1056                     if not standalone_mode:
#    1057                         return rv
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in invoke(self=<Group kiliautoml>, ctx=<click.core.Context object>)
#    1655                 sub_ctx = cmd.make_context(cmd_name, args, parent=ctx)
#    1656                 with sub_ctx:
# -> 1657                     return _process_result(sub_ctx.command.invoke(sub_ctx))
#         _process_result = <function MultiCommand.invoke.<locals>._process_result at 0x7f782aaa1f70>
#         sub_ctx.command.invoke = <bound method Command.invoke of <Command main>>
#         sub_ctx = <click.core.Context object at 0x7f78272e3220>
#    1658
#    1659         # In chain mode we create the contexts step by step, but after the
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in invoke(self=<Command main>, ctx=<click.core.Context object>)
#    1402
#    1403         if self.callback is not None:
# -> 1404             return ctx.invoke(self.callback, **ctx.params)
#         ctx.invoke = <bound method Context.invoke of <click.core.Context object at 0x7f78272e3220>>
#         self.callback = <function main at 0x7f77314b2040>
#         ctx.params = {'api_key': '41d1dd6f-fb37-4d17-9efa-b0e1dd074194', 'project_id': 'clba4yl4g008s0lwmhlu89h7e', 'api_endpoint': 'https://cloud.kili-technology.com/api/label/v2/graphql', 'ml_backend': 'pytorch', 'model_name': None, 'model_repository': None, 'target_job': (), 'ignore_job': (), 'max_assets': None, 'clear_dataset_cache': False, 'randomize_assets': True, 'batch_size': 8, 'verbose': 'INFO', 'parity_filter': 'none', 'label_merge_strategy': 'last', 'epochs': 50, 'asset_status_in': ['LABELED', 'TO_REVIEW', 'REVIEWED'], 'cv_folds': 4, 'dry_run': None, 'erase_error_metadata': None}
#    1405
#    1406     def shell_complete(self, ctx: Context, incomplete: str) -> t.List["CompletionItem"]:
#
# /usr/local/lib/python3.8/dist-packages/click/core.py in invoke(_Context__self=<click.core.Context object>, _Context__callback=<function main>, *args=(), **kwargs={'api_endpoint': 'https://cloud.kili-technology.com/api/label/v2/graphql', 'api_key': '41d1dd6f-fb37-4d17-9efa-b0e1dd074194', 'asset_status_in': ['LABELED', 'TO_REVIEW', 'REVIEWED'], 'batch_size': 8, 'clear_dataset_cache': False, 'cv_folds': 4, 'dry_run': None, 'epochs': 50, 'erase_error_metadata': None, 'ignore_job': (), ...})
#     758         with augment_usage_errors(__self):
#     759             with ctx:
# --> 760                 return __callback(*args, **kwargs)
#         global __callback = undefined
#         args = ()
#         kwargs = {'api_key': '41d1dd6f-fb37-4d17-9efa-b0e1dd074194', 'project_id': 'clba4yl4g008s0lwmhlu89h7e', 'api_endpoint': 'https://cloud.kili-technology.com/api/label/v2/graphql', 'ml_backend': 'pytorch', 'model_name': None, 'model_repository': None, 'target_job': (), 'ignore_job': (), 'max_assets': None, 'clear_dataset_cache': False, 'randomize_assets': True, 'batch_size': 8, 'verbose': 'INFO', 'parity_filter': 'none', 'label_merge_strategy': 'last', 'epochs': 50, 'asset_status_in': ['LABELED', 'TO_REVIEW', 'REVIEWED'], 'cv_folds': 4, 'dry_run': None, 'erase_error_metadata': None}
#     761
#     762     def forward(
#
# /content/automl/commands/label_errors.py in main(project_id='clba4yl4g008s0lwmhlu89h7e', api_endpoint='https://cloud.kili-technology.com/api/label/v2/graphql', api_key='41d1dd6f-fb37-4d17-9efa-b0e1dd074194', clear_dataset_cache=False, ml_backend='pytorch', target_job=(), ignore_job=(), model_repository=None, dry_run=None, epochs=50, asset_status_in=['LABELED', 'TO_REVIEW', 'REVIEWED'], label_merge_strategy='last', max_assets=None, randomize_assets=True, batch_size=8, model_name=None, parity_filter='none', verbose='INFO', cv_folds=4, erase_error_metadata=None)
#     302         if found_errors:
#     303             if not dry_run:
# --> 304                 upload_errors_to_kili(found_errors, kili, project_id)
#         global upload_errors_to_kili = <function upload_errors_to_kili at 0x7f77314a7d30>
#         found_errors = ErrorRecap(external_id_array=['736', '799', '628', '624', '503', '665', '130', '212', '676', '514', '92', '265', '745', '680', '235', '188', '639', '596', '740', '546', '795', '625', '525', '681', '278', '619', '781', '539', '230', '59', '516', '241', '504', '253', '12', '571', '545', '687', '644', '21', '138', '635', '88', '623', '251', '145', '132', '529', '515', '507', '636', '240', '617', '297', '182', '218', '612', '293', '83', '583', '519', '754', '118', '594', '704', '186', '75', '578', '116', '714', '779', '764', '763', '752', '535', '662', '633', '207', '254', '201', '179', '15', '106', '748', '756', '96', '8', '279', '694', '695', '294', '512', '620', '66', '679', '660', '198', '731', '171', '692', '735', '652', '119', '609', '576', '172', '147', '100', '168', '760', '540', '786', '200', '651', '140', '74', '22', '192', '524', '14', '616', '258', '42', '148', '107', '262', '86', '269', '178', '131', '762', '663', '643', '595', '672', '646', '626', '759', '702', '286', '655', '51', '690', '517', '177', '555', '784', '237', '68', '164', '211', '193', '155', '775', '105', '45', '189', '60', '603', '158', '266', '184', '90', '221', '63', '591', '649', '688', '526', '638', '580', '705', '110', '285', '187', '149', '561', '627', '255', '718', '176', '19', '28', '227', '143', '509', '780', '215', '113', '701', '611', '782', '602', '513', '631', '11', '697', '600', '508', '23', '13', '722', '125', '674', '703', '162', '734', '52', '87', '183', '53', '154', '245', '69', '39', '730', '190', '541', '282', '247', '291', '26', '566', '76', '141', '209', '170', '2', '564', '732', '707', '156', '77', '180', '139', '213', '575', '618', '72', '766', '62', '607', '17', '778', '791', '746', '33', '261', '129', '647', '137', '18', '708', '144', '742', '641', '4', '37', '268', '725', '153', '557', '202', '502', '622', '289', '767', '133', '161', '267', '737', '280', '20', '666', '585', '536', '120', '668', '614', '787', '41', '696', '288', '658', '773', '257', '244', '518', '556', '160', '547', '277', '621', '111', '151', '531', '79', '249', '743', '642', '713', '657', '604', '199', '656', '194', '686', '753', '205', '559', '246', '560', '551', '85', '738', '47', '7', '558', '798', '538', '606', '226', '38', '533', '236', '572', '93', '768', '751', '229', '667', '550', '98', '757', '55', '709', '206', '31', '50', '530', '534', '783', '678', '210', '601', '181', '769', '608', '49', '48', '97', '208', '554', '124', '242', '295', '292', '720', '599', '109', '615', '542', '716', '121', '263', '597', '169', '16', '34', '577', '788', '723', '562', '36', '3', '698', '739', '117', '675', '501', '10', '173', '682', '115', '710', '61', '231', '264', '728', '637', '727', '543', '700', '770', '565', '102', '553', '741', '693', '634', '108', '684', '510', '677', '135', '84', '797', '243', '537', '65', '64', '592', '272', '744', '35', '248', '574', '43', '40', '290', '123', '29', '122', '157', '613', '699', '661', '9', '733', '165', '506', '0', '712', '598', '729', '82', '650', '191', '689', '101', '511', '654', '527', '630', '152', '520', '645', '54', '259', '91', '590', '256', '706', '568', '648', '671', '1', '232', '755', '222', '150', '726', '174', '528', '593', '136', '584', '721', '653', '549', '58', '569', '685', '5', '691', '283', '128', '761', '239', '683', '195', '197', '724', '505', '719', '772', '715', '747', '521', '78', '56', '640', '24', '586', '750', '252', '260', '70', '112', '185', '204', '298', '777', '219', '299', '582', '134', '275', '287', '581', '126', '794', '271', '146', '669', '605', '711', '217', '522', '216', '67', '274', '610', '523', '789', '234', '57', '532', '224', '276', '588', '673', '167', '796', '175', '73', '273', '214', '563', '579', '166', '573', '664', '771', '765', '103', '785', '81', '296', '233', '46', '71', '196', '570', '500', '80', '587', '127', '749', '670', '44', '270', '552', '567', '99', '589', '94', '793', '544', '220', '159', '776', '548', '790', '163', '6', '284', '659', '225' ...
#         kili = Kili()
#         project_id = 'clba4yl4g008s0lwmhlu89h7e'
#     305
#     306     logger.success("label_errors command finished successfully!")
#
# /content/automl/commands/label_errors.py in upload_errors_to_kili(error_recap=ErrorRecap(external_id_array=['736', '799', '628...', '25', '114'], id_array=[], errors_by_asset=[]), kili=Kili(), project_id='clba4yl4g008s0lwmhlu89h7e')
#      56     first = min(100, len(id_errors_tuples))
#      57     for skip in tqdm(
# ---> 58         range(0, len(id_errors_tuples), first),
#         global range = undefined
#         global len = undefined
#         id_errors_tuples = []
#         first = 0
#      59         desc="Updating asset metadata with labeling error flag",
#      60     ):
#
# ValueError: range() arg 3 must not be zero

# %% [markdown]
# You can see in the project that several uncorrectly labeled images have been spotted.

# %%
print(f"{KILI_URL}label/projects/{project_id}/menu/queue?currentPage=1&metadata%5Blabeling_error%5D=true&pageSize=20")
# Out:
# https://cloud.kili-technology.com/label/projects/clba4yl4g008s0lwmhlu89h7e/menu/queue?currentPage=1&metadata%5Blabeling_error%5D=true&pageSize=20
